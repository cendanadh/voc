# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv('selected_kpi_agg.csv')
del df['Unnamed: 0']

# %%
df
# Out:
#      location_id       location  enodeb_share  \
# 0           1101       SIMEULUE     98.819889
# 1           1102   ACEH SINGKIL     70.846563
# 2           1103   ACEH SELATAN     90.042483
# 3           1104  ACEH TENGGARA     90.791036
# 4           1105     ACEH TIMUR     81.575234
# ..           ...            ...           ...
# 510         9433         PUNCAK     45.689655
# 511         9434        DOGIYAI     50.517241
# 512         9435     INTAN JAYA     74.597701
# 513         9436         DEIYAI     34.022989
# 514         9471  KOTA JAYAPURA     96.393702
#
#      onx_avg_initialbufferinterval_overall  cei_score  \
# 0                              3894.755909  39.202889
# 1                              3814.646311  47.259552
# 2                              4210.374871  43.589083
# 3                              5796.215219  35.139632
# 4                              5000.427586  44.206753
# ..                                     ...        ...
# ...

# %%
df.describe()
# Out:
#        location_id  enodeb_share  onx_avg_initialbufferinterval_overall  \
# count   515.000000    515.000000                             514.000000
# mean   4568.687379     63.130021                            4201.762923
# std    2681.286023     22.349401                            1174.670241
# min    1101.000000      0.000000                            2867.851924
# 25%    1803.500000     41.858753                            3593.669666
# 50%    3571.000000     63.808865                            3917.900312
# 75%    7187.500000     80.153382                            4484.407871
# max    9471.000000    100.000000                           18247.500000
#
#         cei_score  call_setup_success_rate  ccsr_voice_rate
# count  514.000000               515.000000       514.000000
# mean    54.990112                99.153884        99.514638
# std      6.746189                 2.357748         0.384337
# min     29.751451                61.190477        97.577714
# ...

# %% [markdown]
# # Get kpi score

# %%
month = input('Enter Month : ')
month_list = month.split(' ')

kpi_score = pd.read_csv('kpi_score.csv')

if len(month_list) == 1:
    kpi_score = kpi_score[['kpi_name', month_list[0]]]

elif len(month_list) > 1:
    kpi_score['avg_threshold'] = kpi_score[month_list].mean(axis=1)

kpi_score
# Out:
# Enter Month :  1
#                                              kpi_name   1
# 0   dl_resource_block_utilization_rate_relactuserd... NaN
# 1   max_resource_block_utilization_rate_relactuser... NaN
# 2             nr_prb_utilization_dl_rate_relactuserdl NaN
# 3             nr_prb_utilization_ul_rate_relactuserdl NaN
# 4   ul_resource_block_utilization_rate_relactuserd... NaN
# 5                                   availability_rate NaN
# 6                             call_setup_success_rate NaN
# 7                                     ccsr_voice_rate NaN
# 8                                nr_availability_rate NaN
# 9                               nr_retainability_rate NaN
# 10                           nr_sn_setup_success_rate NaN
# 11            nr_user_throughput_dl_mbps_relactuserdl NaN
# 12                                   ows_availability NaN
# 13                                         packetloss NaN
# 14                                   sd_setup_sr_rate NaN
# ...

# %%
def kpi_score_func(x):
    col_list = list(x.columns)

    for col in col_list:
        if col in kpi_score.iloc[:,0].to_list():
            if len(month_list) == 1:
                x[col] = x[col].apply(lambda x: 100 if x >= kpi_score.loc[col, month_list[0]] else 0)
            else:
                return 'else'


kpi_score_func(df)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[229], line 12
#       8             else:
#       9                 return 'else'
# ---> 12 kpi_score_func(df)
#      13 df
#
# Cell In[229], line 7, in kpi_score_func(x)
#       5 if col in kpi_score.iloc[:,0].to_list():
#       6     if len(month_list) == 1:
# ----> 7         x[col] = x[col].apply(lambda x: 100 if x >= kpi_score.loc[col, month_list[0]] else 0)
#       8     else:
#       9         return 'else'
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
# ...

# %%
col_list = list(df.columns)
for col in col_list:
    if col in kpi_score.iloc[:,0].to_list():
        print('yes')
    else:
        print('no')
# Out:
# no
# no
# yes
# yes
# yes
# yes
# yes
